# %%
# for data manipulation
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from gensim.models import Word2Vec
import gensim.downloader as api
from transformers import BertTokenizer, BertModel
import torch
import warnings
import scipy.sparse

# for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# DL Libraries
import tensorflow as tf
from tensorflow import keras
from keras.layers import Conv2D , MaxPooling2D ,Dropout , Flatten , Dense ,BatchNormalization ,Concatenate ,Input 
from keras.models import Sequential ,Model
import json

# other libraries
import cv2
import os
import glob
from PIL import Image
import string
import re
from nltk.corpus import stopwords
from collections import Counter
from nltk.tokenize import WordPunctTokenizer
from nltk.stem import WordNetLemmatizer
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.decomposition import PCA, TruncatedSVD  
from sklearn.naive_bayes import MultinomialNB
from sklearn.cluster import KMeans, AgglomerativeClustering, SpectralClustering
from sklearn.ensemble import RandomForestClassifier # Added RandomForestClassifier
from sklearn.metrics.cluster import adjusted_mutual_info_score, adjusted_rand_score # Changed metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score # Import classification metrics

# Model
import tensorflow as tf
import diptest
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers, models, applications
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import MobileNetV2, ResNet50
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler, LabelEncoder
from tensorflow.keras.applications.mobilenet import MobileNet, preprocess_input
from sklearn.metrics import adjusted_mutual_info_score, adjusted_rand_score
from sklearn.svm import SVC
from scipy.stats import iqr # For Silverman's rule
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MultiLabelBinarizer

# RLAC MODEL
from sklearn.random_projection import GaussianRandomProjection
from scipy.stats import gaussian_kde
from scipy.signal import find_peaks  
from sklearn.neighbors import KernelDensity  
from sklearn.model_selection import GridSearchCV, LeaveOneOut
from scipy import stats
from scipy.special import eval_hermitenorm  # For normalized Hermite polynomials H_n(x)
from scipy.stats import skew
from scipy.stats import norm
from sklearn.metrics import (adjusted_mutual_info_score, adjusted_rand_score, 
                             homogeneity_score, completeness_score, v_measure_score,
                             fowlkes_mallows_score, silhouette_score, calinski_harabasz_score,
                             davies_bouldin_score)
import warnings
warnings.simplefilter(action='ignore')

# %%
import arff 

# Load the ARFF file
dataset = arff.load(open(r'dartboard1 .arff'))

# Access the data and attributes
data = np.array(dataset['data'])
attributes = dataset['attributes']

# %%
# Print some information (optional)
print("Attributes:", attributes)
print("Data shape:", data.shape)
# Out:
# Attributes: [('a0', 'REAL'), ('a1', 'REAL'), ('class', ['0', '1', '2', '3'])]
# Data shape: (1000, 3)

# %%
df = pd.DataFrame(data, columns=[attr[0] for attr in attributes])
print(df.head())
# Out:
#           a0        a1 class
# 0       -0.1       0.5     0
# 1  -0.100126  0.510052     0
# 2  -0.100505  0.520098     0
# 3  -0.101136  0.530131     0
# 4   -0.10202  0.540145     0

# %%
# 2. Prepare features (X) and labels (y)
X = df[['a0', 'a1']].values  # Features (x and y coordinates)
y_train = df['class'].values      # Labels

# %%
from sklearn.preprocessing import StandardScaler

# Scale the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X)

# %%
results = []

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering  
from sklearn.cluster import SpectralClustering

# %%
# 4. Apply clustering algorithms
#kmeans = KMeans(n_clusters=4)  # Specify the number of clusters
kmeans = KMeans(n_clusters=4, n_init=10, init='random', algorithm='lloyd', max_iter=10, random_state=42)
kmeans_labels = kmeans.fit_predict(X_train)

ami_km = adjusted_mutual_info_score(y_train, kmeans_labels)
ari_km = adjusted_rand_score(y_train, kmeans_labels)

results.append(["KMeans", ami_km, ari_km])

# %%
ncut = SpectralClustering(n_clusters=4, affinity='nearest_neighbors', assign_labels='kmeans', n_jobs=-1)  # Example parameters, tune as needed
ncut_labels = ncut.fit_predict(X_train)

ami_nc = adjusted_mutual_info_score(y_train, ncut_labels)
ari_nc = adjusted_rand_score(y_train, ncut_labels)

results.append(["NClust", ami_nc, ari_nc])

# %%
#hclust = AgglomerativeClustering(n_clusters=4, linkage='ward') # ward linkage is often a good choice
hclust = AgglomerativeClustering(n_clusters=4, linkage='single', metric='euclidean')
hclust_labels = hclust.fit_predict(X_train)

ami_hc = adjusted_mutual_info_score(y_train, hclust_labels)
ari_hc = adjusted_rand_score(y_train, hclust_labels)

results.append(["HClust(single)", ami_hc, ari_hc])

# %%
# Create Pandas DataFrame
results_df = pd.DataFrame(results, columns=["Model", "AMI", "ARI"])

print(results_df)
# Out:
#             Model      AMI       ARI
# 0          KMeans -0.00327 -0.003012
# 1          NClust  1.00000  1.000000
# 2  HClust(single)  1.00000  1.000000

# %%
import sys
import os

# 1. Get the path of the parent directory (Project_Root)
# '..' means "go up one level"
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))

# 2. Add it to Python's search path if not already there
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# 3. Now you can import normally
from rlac import RLAC
from mdh import MDH

#print("Successfully imported models from:", parent_dir)

# %%
import warnings
from sklearn.metrics import adjusted_rand_score, adjusted_mutual_info_score

# Import your custom models
from rlac import RLAC
from mdh import MDH

# --- CONFIGURATION ---
# Target clusters for Aggregation dataset (should be 7)
n_clusters = len(set(y_train))

# RLAC Parameters
rlac_methods = [
    'depth_ratio', 'dip', 'holes', 'min_kurt', 'max_kurt', 
    'negentropy', 'skewness', 'fisher', 'hermite', 'friedman_tukey'
]
rlac_params = {
    'random_state': [32, 42, 43, 44, 45],
    'bw_adjust': [0.2, 0.3, 0.4, 0.5],
    'r': [50, 100, 200, 300, 500]
}
# MDH Parameters (Same as Anuran configuration)
mdh_config = {
    "h_multiplier": 1.0,
    "alphamax_val": 0.9,
    "alpha_steps": 5,
    "random_state": 42
}

results = []

print(f"\nStarting Benchmark on Aggregation Dataset (n={len(X_train)}, k={n_clusters})...")
print("-" * 80)

# ==========================================
# 1. RLAC LOOP
# ==========================================
for method in rlac_methods:
    for r_val in rlac_params['r']:
        for bw in rlac_params['bw_adjust']:
            for seed in rlac_params['random_state']:
                
                # 1. Print parameters BEFORE running
                param_str = f"r={r_val}, bw={bw}, s={seed}"
                print(f"\nRunning RLAC {method:<15} | {param_str} ... ", end="")
                
                try:
                    # 2. Instantiate & Fit
                    model = RLAC(
                        n_clusters=n_clusters,
                        method=method,
                        r=r_val,
                        bw_adjust=bw,
                        random_state=seed,
                        plot=False
                    )
                    
                    with warnings.catch_warnings():
                        warnings.filterwarnings("ignore", category=UserWarning)
                        model.fit(X_train)
                    
                    # 3. Evaluate
                    ami = adjusted_mutual_info_score(y_train, model.labels_)
                    ari = adjusted_rand_score(y_train, model.labels_)
                    
                    # 4. Log Success
                    print(f"Done (AMI: {ami:.4f})")
                    
                    results.append({
                        'Model': 'RLAC',
                        'Method': method,
                        'Params': param_str,
                        'AMI': ami,
                        'ARI': ari
                    })
                    
                except Exception as e:
                    print(f"FAILED. Error: {e}")
                    results.append({
                        'Model': 'RLAC', 'Method': method, 'Params': param_str,
                        'AMI': -1, 'ARI': -1
                    })

# ==========================================
# 2. MDH RUN
# ==========================================
print(f"\nRunning MDH {'Standard':<15} | h=1.0, a=0.9 ... ")
try:
    mdh_model = MDH(
        n_clusters=n_clusters,
        h_multiplier=mdh_config['h_multiplier'],
        alphamax_val=mdh_config['alphamax_val'],
        alpha_steps=mdh_config['alpha_steps'],
        random_state=mdh_config['random_state'],
        verbose=False,
        plot=False
    )
    
    mdh_model.fit(X_train)
    
    ami_mdh = adjusted_mutual_info_score(y_train, mdh_model.labels_)
    ari_mdh = adjusted_rand_score(y_train, mdh_model.labels_)
    
    print(f"Done (AMI: {ami_mdh:.4f})")
    
    results.append({
        'Model': 'MDH',
        'Method': 'Standard',
        'Params': 'Fixed',
        'AMI': ami_mdh,
        'ARI': ari_mdh
    })
    
except Exception as e:
    print(f"FAILED. Error: {e}")

# ==========================================
# 3. RESULTS TABLE
# ==========================================
print("\n" + "="*80)
print("FINAL RESULTS (ALL MODELS - SORTED BY AMI)")
print("="*80)

# 1. Create DataFrame
results_df = pd.DataFrame(results).sort_values(by='AMI', ascending=False)

# 2. Print FULL table (no truncation)
# index=False hides the row numbers for a cleaner look
print(results_df.to_string(index=False))
# Out:
# Starting Benchmark on Aggregation Dataset (n=1000, k=4)...
# --------------------------------------------------------------------------------
#
# Running RLAC depth_ratio     | r=50, bw=0.2, s=32 ... [DEPTH_RATIO] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 26 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 21 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 1 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=50, bw=0.2, s=42 ... [DEPTH_RATIO] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 8 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 49 | Score: 0.2197
# Iter 3: Split Cluster 2 (Size: 902) via Proj 1 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=50, bw=0.2, s=43 ... [DEPTH_RATIO] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 3 | Score: 0.2145
# Iter 2: Split Cluster 0 (Size: 951) via Proj 10 | Score: 0.2197
# Iter 3: Split Cluster 2 (Size: 902) via Proj 1 | Score: 0.2191
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2175)
#
# Running RLAC depth_ratio     | r=50, bw=0.2, s=44 ... [DEPTH_RATIO] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 31 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 26 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 14 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=50, bw=0.2, s=45 ... [DEPTH_RATIO] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 21 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 37 | Score: 0.2197
# Iter 3: Split Cluster 2 (Size: 902) via Proj 3 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=50, bw=0.3, s=32 ... [DEPTH_RATIO] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 0 | Score: 0.1630
# Iter 2: Split Cluster 0 (Size: 953) via Proj 21 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 16 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=50, bw=0.3, s=42 ... [DEPTH_RATIO] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 2 | Score: 0.1630
# Iter 2: Split Cluster 1 (Size: 953) via Proj 49 | Score: 0.1674
# Iter 3: Split Cluster 1 (Size: 922) via Proj 1 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=50, bw=0.3, s=43 ... [DEPTH_RATIO] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 1 | Score: 0.1630
# Iter 2: Split Cluster 0 (Size: 953) via Proj 3 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 4 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=50, bw=0.3, s=44 ... [DEPTH_RATIO] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 0 | Score: 0.1630
# Iter 2: Split Cluster 0 (Size: 953) via Proj 26 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 20 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=50, bw=0.3, s=45 ... [DEPTH_RATIO] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 14 | Score: 0.1630
# Iter 2: Split Cluster 1 (Size: 953) via Proj 37 | Score: 0.1674
# Iter 3: Split Cluster 1 (Size: 922) via Proj 9 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=50, bw=0.4, s=32 ... [DEPTH_RATIO] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 1 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 26 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 5 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=50, bw=0.4, s=42 ... [DEPTH_RATIO] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 1 | Score: 0.1163
# Iter 2: Split Cluster 0 (Size: 956) via Proj 8 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 2 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=50, bw=0.4, s=43 ... [DEPTH_RATIO] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 5 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 10 | Score: 0.1401
# Iter 3: Split Cluster 2 (Size: 925) via Proj 11 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=50, bw=0.4, s=44 ... [DEPTH_RATIO] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 14 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 31 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 3 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=50, bw=0.4, s=45 ... [DEPTH_RATIO] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 3 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 21 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 14 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=50, bw=0.5, s=32 ... [DEPTH_RATIO] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 16 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 26 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 17 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=50, bw=0.5, s=42 ... [DEPTH_RATIO] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 1 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 8 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 49 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=50, bw=0.5, s=43 ... [DEPTH_RATIO] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 4 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 32 | Score: 0.1040
# Iter 3: Split Cluster 1 (Size: 926) via Proj 10 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=50, bw=0.5, s=44 ... [DEPTH_RATIO] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 20 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 31 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 6 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=50, bw=0.5, s=45 ... [DEPTH_RATIO] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 9 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 21 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 37 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=100, bw=0.2, s=32 ... [DEPTH_RATIO] Generating 100 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 17 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 6 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 3 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=100, bw=0.2, s=42 ... [DEPTH_RATIO] Generating 100 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 8 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 22 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 0 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=100, bw=0.2, s=43 ... [DEPTH_RATIO] Generating 100 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 43 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 72 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 8 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=100, bw=0.2, s=44 ... [DEPTH_RATIO] Generating 100 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 0 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 21 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 16 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=100, bw=0.2, s=45 ... [DEPTH_RATIO] Generating 100 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 20 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 35 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 0 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=100, bw=0.3, s=32 ... [DEPTH_RATIO] Generating 100 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 0 | Score: 0.1630
# Iter 2: Split Cluster 0 (Size: 953) via Proj 6 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 7 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=100, bw=0.3, s=42 ... [DEPTH_RATIO] Generating 100 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 2 | Score: 0.1630
# Iter 2: Split Cluster 1 (Size: 953) via Proj 22 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 24 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=100, bw=0.3, s=43 ... [DEPTH_RATIO] Generating 100 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 3 | Score: 0.1630
# Iter 2: Split Cluster 1 (Size: 953) via Proj 72 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 33 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=100, bw=0.3, s=44 ... [DEPTH_RATIO] Generating 100 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 5 | Score: 0.1630
# Iter 2: Split Cluster 1 (Size: 953) via Proj 21 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 8 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=100, bw=0.3, s=45 ... [DEPTH_RATIO] Generating 100 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 11 | Score: 0.1630
# Iter 2: Split Cluster 1 (Size: 953) via Proj 35 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 4 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=100, bw=0.4, s=32 ... [DEPTH_RATIO] Generating 100 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 3 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 17 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 5 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=100, bw=0.4, s=42 ... [DEPTH_RATIO] Generating 100 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 0 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 8 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 2 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=100, bw=0.4, s=43 ... [DEPTH_RATIO] Generating 100 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 8 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 43 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 3 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=100, bw=0.4, s=44 ... [DEPTH_RATIO] Generating 100 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 16 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 0 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 5 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=100, bw=0.4, s=45 ... [DEPTH_RATIO] Generating 100 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 0 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 20 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 11 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=100, bw=0.5, s=32 ... [DEPTH_RATIO] Generating 100 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 7 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 17 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 6 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=100, bw=0.5, s=42 ... [DEPTH_RATIO] Generating 100 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 24 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 8 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 22 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=100, bw=0.5, s=43 ... [DEPTH_RATIO] Generating 100 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 33 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 43 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 1 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=100, bw=0.5, s=44 ... [DEPTH_RATIO] Generating 100 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 8 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 0 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 21 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=100, bw=0.5, s=45 ... [DEPTH_RATIO] Generating 100 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 4 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 20 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 35 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=200, bw=0.2, s=32 ... [DEPTH_RATIO] Generating 200 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 27 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 21 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 1 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=200, bw=0.2, s=42 ... [DEPTH_RATIO] Generating 200 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 4 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 72 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 1 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=200, bw=0.2, s=43 ... [DEPTH_RATIO] Generating 200 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 15 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 3 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 4 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=200, bw=0.2, s=44 ... [DEPTH_RATIO] Generating 200 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 86 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 10 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 32 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=200, bw=0.2, s=45 ... [DEPTH_RATIO] Generating 200 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 23 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 41 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 5 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=200, bw=0.3, s=32 ... [DEPTH_RATIO] Generating 200 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 0 | Score: 0.1630
# Iter 2: Split Cluster 0 (Size: 953) via Proj 21 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 2 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=200, bw=0.3, s=42 ... [DEPTH_RATIO] Generating 200 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 2 | Score: 0.1630
# Iter 2: Split Cluster 1 (Size: 953) via Proj 72 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 3 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=200, bw=0.3, s=43 ... [DEPTH_RATIO] Generating 200 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 1 | Score: 0.1630
# Iter 2: Split Cluster 0 (Size: 953) via Proj 3 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 20 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=200, bw=0.3, s=44 ... [DEPTH_RATIO] Generating 200 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 0 | Score: 0.1630
# Iter 2: Split Cluster 0 (Size: 953) via Proj 10 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 8 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=200, bw=0.3, s=45 ... [DEPTH_RATIO] Generating 200 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 11 | Score: 0.1630
# Iter 2: Split Cluster 1 (Size: 953) via Proj 41 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 6 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=200, bw=0.4, s=32 ... [DEPTH_RATIO] Generating 200 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 1 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 27 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 5 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=200, bw=0.4, s=42 ... [DEPTH_RATIO] Generating 200 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 1 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 4 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 2 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=200, bw=0.4, s=43 ... [DEPTH_RATIO] Generating 200 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 4 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 15 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 10 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=200, bw=0.4, s=44 ... [DEPTH_RATIO] Generating 200 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 32 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 86 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 5 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=200, bw=0.4, s=45 ... [DEPTH_RATIO] Generating 200 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 5 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 23 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 11 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=200, bw=0.5, s=32 ... [DEPTH_RATIO] Generating 200 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 2 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 27 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 21 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=200, bw=0.5, s=42 ... [DEPTH_RATIO] Generating 200 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 3 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 4 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 51 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=200, bw=0.5, s=43 ... [DEPTH_RATIO] Generating 200 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 20 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 15 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 3 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=200, bw=0.5, s=44 ... [DEPTH_RATIO] Generating 200 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 8 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 86 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 4 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=200, bw=0.5, s=45 ... [DEPTH_RATIO] Generating 200 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 6 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 23 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 21 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=300, bw=0.2, s=32 ... [DEPTH_RATIO] Generating 300 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 0 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 67 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 10 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=300, bw=0.2, s=42 ... [DEPTH_RATIO] Generating 300 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 36 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 103 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 19 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=300, bw=0.2, s=43 ... [DEPTH_RATIO] Generating 300 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 43 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 11 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 4 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=300, bw=0.2, s=44 ... [DEPTH_RATIO] Generating 300 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 6 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 3 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 11 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=300, bw=0.2, s=45 ... [DEPTH_RATIO] Generating 300 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 27 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 35 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 0 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=300, bw=0.3, s=32 ... [DEPTH_RATIO] Generating 300 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 5 | Score: 0.1630
# Iter 2: Split Cluster 1 (Size: 953) via Proj 67 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 7 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=300, bw=0.3, s=42 ... [DEPTH_RATIO] Generating 300 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 2 | Score: 0.1630
# Iter 2: Split Cluster 1 (Size: 953) via Proj 103 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 1 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=300, bw=0.3, s=43 ... [DEPTH_RATIO] Generating 300 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 1 | Score: 0.1630
# Iter 2: Split Cluster 0 (Size: 953) via Proj 11 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 0 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=300, bw=0.3, s=44 ... [DEPTH_RATIO] Generating 300 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 0 | Score: 0.1630
# Iter 2: Split Cluster 0 (Size: 953) via Proj 3 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 2 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=300, bw=0.3, s=45 ... [DEPTH_RATIO] Generating 300 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 11 | Score: 0.1630
# Iter 2: Split Cluster 1 (Size: 953) via Proj 35 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 1 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=300, bw=0.4, s=32 ... [DEPTH_RATIO] Generating 300 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 10 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 0 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 5 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=300, bw=0.4, s=42 ... [DEPTH_RATIO] Generating 300 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 19 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 36 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 2 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=300, bw=0.4, s=43 ... [DEPTH_RATIO] Generating 300 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 4 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 43 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 3 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=300, bw=0.4, s=44 ... [DEPTH_RATIO] Generating 300 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 11 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 6 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 12 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=300, bw=0.4, s=45 ... [DEPTH_RATIO] Generating 300 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 0 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 27 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 11 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=300, bw=0.5, s=32 ... [DEPTH_RATIO] Generating 300 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 7 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 0 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 32 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=300, bw=0.5, s=42 ... [DEPTH_RATIO] Generating 300 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 1 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 36 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 4 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=300, bw=0.5, s=43 ... [DEPTH_RATIO] Generating 300 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 0 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 43 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 2 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=300, bw=0.5, s=44 ... [DEPTH_RATIO] Generating 300 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 2 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 6 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 3 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=300, bw=0.5, s=45 ... [DEPTH_RATIO] Generating 300 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 1 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 27 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 19 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=500, bw=0.2, s=32 ... [DEPTH_RATIO] Generating 500 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 17 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 49 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 1 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=500, bw=0.2, s=42 ... [DEPTH_RATIO] Generating 500 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 51 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 22 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 1 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=500, bw=0.2, s=43 ... [DEPTH_RATIO] Generating 500 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 1 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 3 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 8 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=500, bw=0.2, s=44 ... [DEPTH_RATIO] Generating 500 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 39 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 5 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 2 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=500, bw=0.2, s=45 ... [DEPTH_RATIO] Generating 500 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 19 | Score: 0.2145
# Iter 2: Split Cluster 1 (Size: 951) via Proj 35 | Score: 0.2197
# Iter 3: Split Cluster 1 (Size: 902) via Proj 3 | Score: 0.2250
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.2192)
#
# Running RLAC depth_ratio     | r=500, bw=0.3, s=32 ... [DEPTH_RATIO] Generating 500 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 0 | Score: 0.1630
# Iter 2: Split Cluster 0 (Size: 953) via Proj 49 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 7 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=500, bw=0.3, s=42 ... [DEPTH_RATIO] Generating 500 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 4 | Score: 0.1630
# Iter 2: Split Cluster 0 (Size: 953) via Proj 22 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 9 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=500, bw=0.3, s=43 ... [DEPTH_RATIO] Generating 500 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 2 | Score: 0.1630
# Iter 2: Split Cluster 0 (Size: 953) via Proj 3 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 20 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=500, bw=0.3, s=44 ... [DEPTH_RATIO] Generating 500 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 4 | Score: 0.1630
# Iter 2: Split Cluster 0 (Size: 953) via Proj 5 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 7 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=500, bw=0.3, s=45 ... [DEPTH_RATIO] Generating 500 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 11 | Score: 0.1630
# Iter 2: Split Cluster 1 (Size: 953) via Proj 35 | Score: 0.1674
# Iter 3: Split Cluster 2 (Size: 922) via Proj 1 | Score: 0.1731
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1833)
#
# Running RLAC depth_ratio     | r=500, bw=0.4, s=32 ... [DEPTH_RATIO] Generating 500 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 1 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 17 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 5 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=500, bw=0.4, s=42 ... [DEPTH_RATIO] Generating 500 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 1 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 51 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 5 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=500, bw=0.4, s=43 ... [DEPTH_RATIO] Generating 500 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 8 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 1 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 18 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=500, bw=0.4, s=44 ... [DEPTH_RATIO] Generating 500 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 2 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 39 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 26 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=500, bw=0.4, s=45 ... [DEPTH_RATIO] Generating 500 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 3 | Score: 0.1163
# Iter 2: Split Cluster 1 (Size: 956) via Proj 19 | Score: 0.1401
# Iter 3: Split Cluster 1 (Size: 925) via Proj 11 | Score: 0.1433
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1782)
#
# Running RLAC depth_ratio     | r=500, bw=0.5, s=32 ... [DEPTH_RATIO] Generating 500 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 7 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 17 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 27 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=500, bw=0.5, s=42 ... [DEPTH_RATIO] Generating 500 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 9 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 51 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 22 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=500, bw=0.5, s=43 ... [DEPTH_RATIO] Generating 500 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 20 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 1 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 3 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=500, bw=0.5, s=44 ... [DEPTH_RATIO] Generating 500 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 7 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 39 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 0 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC depth_ratio     | r=500, bw=0.5, s=45 ... [DEPTH_RATIO] Generating 500 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 1 | Score: 0.0699
# Iter 2: Split Cluster 1 (Size: 958) via Proj 19 | Score: 0.1040
# Iter 3: Split Cluster 2 (Size: 926) via Proj 20 | Score: 0.1007
# RLAC (depth_ratio) complete. Final clusters: 4
# Done (AMI: 0.1765)
#
# Running RLAC dip             | r=50, bw=0.2, s=32 ... [DIP] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 5 | Score: 0.0179
# Iter 2: Split Cluster 0 (Size: 951) via Proj 16 | Score: 0.0182
# Iter 3: Split Cluster 2 (Size: 901) via Proj 21 | Score: 0.0174
# RLAC (dip) complete. Final clusters: 4
# Done (AMI: 0.2193)
#
# Running RLAC dip             | r=50, bw=0.2, s=42 ... [DIP] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 2 | Score: 0.0179
# Iter 2: Split Cluster 0 (Size: 951) via Proj 1 | Score: 0.0182
# Iter 3: Split Cluster 2 (Size: 901) via Proj 49 | Score: 0.0174
# RLAC (dip) complete. Final clusters: 4
# Done (AMI: 0.2193)
#
# Running RLAC dip             | r=50, bw=0.2, s=43 ... [DIP] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 11 | Score: 0.0179
# Iter 2: Split Cluster 0 (Size: 951) via Proj 4 | Score: 0.0182
# Iter 3: Split Cluster 2 (Size: 901) via Proj 3 | Score: 0.0174
# RLAC (dip) complete. Final clusters: 4
# Done (AMI: 0.2193)
#
# Running RLAC dip             | r=50, bw=0.2, s=44 ... [DIP] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 3 | Score: 0.0179
# Iter 2: Split Cluster 0 (Size: 951) via Proj 20 | Score: 0.0182
# Iter 3: Split Cluster 2 (Size: 901) via Proj 26 | Score: 0.0174
# RLAC (dip) complete. Final clusters: 4
# Done (AMI: 0.2193)
#
# Running RLAC dip             | r=50, bw=0.2, s=45 ... [DIP] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 14 | Score: 0.0179
# Iter 2: Split Cluster 0 (Size: 951) via Proj 9 | Score: 0.0182
# Iter 3: Split Cluster 2 (Size: 901) via Proj 37 | Score: 0.0174
# RLAC (dip) complete. Final clusters: 4
# Done (AMI: 0.2193)
#
# Running RLAC dip             | r=50, bw=0.3, s=32 ... [DIP] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 5 | Score: 0.0179
# Iter 2: Split Cluster 1 (Size: 953) via Proj 16 | Score: 0.0182
# Iter 3: Split Cluster 1 (Size: 907) via Proj 17 | Score: 0.0176
# RLAC (dip) complete. Final clusters: 4
# Done (AMI: 0.2088)
#
# Running RLAC dip             | r=50, bw=0.3, s=42 ... [DIP] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 2 | Score: 0.0179
# Iter 2: Split Cluster 1 (Size: 953) via Proj 1 | Score: 0.0182
# Iter 3: Split Cluster 1 (Size: 907) via Proj 49 | Score: 0.0176
# RLAC (dip) complete. Final clusters: 4
# Done (AMI: 0.2088)
#
# Running RLAC dip             | r=50, bw=0.3, s=43 ... [DIP] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 11 | Score: 0.0179
# Iter 2: Split Cluster 1 (Size: 953) via Proj 4 | Score: 0.0182
# Iter 3: Split Cluster 1 (Size: 907) via Proj 32 | Score: 0.0176
# RLAC (dip) complete. Final clusters: 4
# Done (AMI: 0.2088)
#
# Running RLAC dip             | r=50, bw=0.3, s=44 ... [DIP] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 3 | Score: 0.0179
# Iter 2: Split Cluster 1 (Size: 953) via Proj 20 | Score: 0.0182
# Iter 3: Split Cluster 1 (Size: 907) via Proj 6 | Score: 0.0176
# RLAC (dip) complete. Final clusters: 4
# Done (AMI: 0.2088)
#
# Running RLAC dip             | r=50, bw=0.3, s=45 ... [DIP] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 14 | Score: 0.0179
# Iter 2: Split Cluster 1 (Size: 953) via Proj 9 | Score: 0.0182
# Iter 3: Split Cluster 1 (Size: 907) via Proj 37 | Score: 0.0176
# RLAC (dip) complete. Final clusters: 4
# Done (AMI: 0.2088)
#
# Running RLAC dip             | r=50, bw=0.4, s=32 ... [DIP] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 5 | Score: 0.0179
# Iter 2: Split Cluster 1 (Size: 957) via Proj 16 | Score: 0.0181
# Iter 3: Split Cluster 2 (Size: 913) via Proj 42 | Score: 0.0180
# RLAC (dip) complete. Final clusters: 4
# Done (AMI: 0.1985)
#
# Running RLAC dip             | r=50, bw=0.4, s=42 ... [DIP] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 2 | Score: 0.0179
# Iter 2: Split Cluster 1 (Size: 957) via Proj 1 | Score: 0.0181
# Iter 3: Split Cluster 2 (Size: 913) via Proj 22 | Score: 0.0180
# RLAC (dip) complete. Final clusters: 4
# Done (AMI: 0.1985)
#
# Running RLAC dip             | r=50, bw=0.4, s=43 ... [DIP] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 11 | Score: 0.0179
# Iter 2: Split Cluster 1 (Size: 957) via Proj 4 | Score: 0.0181
# Iter 3: Split Cluster 2 (Size: 913) via Proj 10 | Score: 0.0180
# RLAC (dip) complete. Final clusters: 4
# Done (AMI: 0.1985)
#
# Running RLAC dip             | r=50, bw=0.4, s=44 ... [DIP] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 3 | Score: 0.0179
# Iter 2: Split Cluster 1 (Size: 957) via Proj 20 | Score: 0.0181
# Iter 3: Split Cluster 2 (Size: 913) via Proj 45 | Score: 0.0180
# RLAC (dip) complete. Final clusters: 4
# Done (AMI: 0.1985)
#
# Running RLAC dip             | r=50, bw=0.4, s=45 ... [DIP] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 14 | Score: 0.0179
# Iter 2: Split Cluster 1 (Size: 957) via Proj 9 | Score: 0.0181
# Iter 3: Split Cluster 2 (Size: 913) via Proj 11 | Score: 0.0180
# RLAC (dip) complete. Final clusters: 4
# Done (AMI: 0.1985)
#
# Running RLAC dip             | r=50, bw=0.5, s=32 ... [DIP] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 5 | Score: 0.0179
# Iter 2: Split Cluster 1 (Size: 957) via Proj 16 | Score: 0.0181
# Iter 3: Split Cluster 1 (Size: 915) via Proj 17 | Score: 0.0184
# RLAC (dip) complete. Final clusters: 4
# Done (AMI: 0.1951)
#
# Running RLAC dip             | r=50, bw=0.5, s=42 ... [DIP] Generating 50 sparse random projections...
# Starting Clustering: Target=4 clusters.
# Iter 1: Split Cluster 0 (Size: 1000) via Proj 2 | Score: 0.0179
# Iter 2: Split Cluster 1 (Size: 957) via Proj 1 | Score: 0.0181
# Iter 3: Split Cluster 1 (Size: 915) via Proj 8 | Score: 0.0184
# RLAC (dip) complete. Final clusters: 4
# Done (AMI: 0.1769)
#
# ...
#  RLAC     negentropy r=300, bw=0.5, s=43 0.176870 0.034136
#  RLAC     negentropy r=300, bw=0.5, s=32 0.176870 0.034136
#  RLAC     negentropy  r=50, bw=0.5, s=44 0.176870 0.034136
#  RLAC        hermite r=300, bw=0.5, s=45 0.176870 0.034136
#  RLAC        hermite r=300, bw=0.5, s=42 0.176870 0.034136
#  RLAC        hermite r=200, bw=0.5, s=43 0.176870 0.034136
#  RLAC     negentropy  r=50, bw=0.5, s=45 0.176870 0.034136
#  RLAC     negentropy  r=50, bw=0.5, s=32 0.176870 0.034136
#  RLAC     negentropy  r=50, bw=0.5, s=42 0.176870 0.034136
#  RLAC        hermite r=500, bw=0.5, s=43 0.176870 0.034136
#  RLAC        hermite r=500, bw=0.5, s=32 0.176870 0.034136
#  RLAC        hermite r=300, bw=0.5, s=32 0.176870 0.034136
#  RLAC        hermite r=200, bw=0.5, s=42 0.176870 0.034136
#  RLAC       min_kurt r=200, bw=0.5, s=43 0.176870 0.034136
#  RLAC       min_kurt r=200, bw=0.5, s=42 0.176870 0.034136
#  RLAC       min_kurt r=200, bw=0.5, s=32 0.176870 0.034136
#  RLAC       min_kurt  r=50, bw=0.5, s=44 0.176870 0.034136
#  RLAC       min_kurt  r=50, bw=0.5, s=32 0.176870 0.034136
#  RLAC       min_kurt  r=50, bw=0.5, s=42 0.176870 0.034136
#  RLAC        hermite  r=50, bw=0.5, s=42 0.176870 0.034136
#  RLAC        hermite  r=50, bw=0.5, s=44 0.176870 0.034136
#  RLAC        hermite  r=50, bw=0.5, s=32 0.176870 0.034136
#  RLAC        hermite r=100, bw=0.5, s=42 0.176870 0.034136
#  RLAC        hermite r=100, bw=0.5, s=43 0.176870 0.034136
#  RLAC        hermite r=100, bw=0.5, s=45 0.176870 0.034136
#  RLAC        hermite r=100, bw=0.5, s=32 0.176870 0.034136
#  RLAC        hermite r=100, bw=0.5, s=44 0.176870 0.034136
#  RLAC        hermite r=200, bw=0.5, s=32 0.176870 0.034136
#  RLAC       min_kurt r=500, bw=0.5, s=43 0.176870 0.034136
#  RLAC       min_kurt r=300, bw=0.5, s=42 0.176870 0.034136
#  RLAC       min_kurt r=300, bw=0.5, s=32 0.176870 0.034136
#  RLAC       min_kurt r=100, bw=0.5, s=43 0.176870 0.034136
#  RLAC       min_kurt r=100, bw=0.5, s=42 0.176870 0.034136
#  RLAC       min_kurt r=100, bw=0.5, s=45 0.176870 0.034136
#  RLAC       min_kurt r=100, bw=0.5, s=44 0.176870 0.034136
#  RLAC       min_kurt r=300, bw=0.5, s=45 0.176870 0.034136
#  RLAC       min_kurt r=100, bw=0.5, s=32 0.176870 0.034136
#  RLAC       min_kurt r=500, bw=0.5, s=32 0.176870 0.034136
#  RLAC            dip  r=50, bw=0.5, s=42 0.176870 0.034136
#  RLAC     negentropy r=200, bw=0.5, s=42 0.176870 0.034136
#  RLAC     negentropy r=500, bw=0.5, s=45 0.176870 0.034136
#  RLAC     negentropy r=200, bw=0.5, s=44 0.176870 0.034136
#  RLAC     negentropy r=500, bw=0.5, s=44 0.176870 0.034136
#  RLAC     negentropy r=200, bw=0.5, s=45 0.176870 0.034136
#  RLAC     negentropy r=500, bw=0.5, s=32 0.176870 0.034136
#  RLAC         fisher r=200, bw=0.4, s=42 0.176503 0.033585
#  RLAC         fisher r=200, bw=0.4, s=32 0.176503 0.033585
#  RLAC         fisher r=200, bw=0.4, s=43 0.176503 0.033585
#  RLAC         fisher r=100, bw=0.4, s=42 0.176503 0.033585
#  RLAC         fisher  r=50, bw=0.4, s=45 0.176503 0.033585
#  RLAC         fisher r=100, bw=0.4, s=43 0.176503 0.033585
#  RLAC         fisher r=100, bw=0.4, s=44 0.176503 0.033585
#  RLAC         fisher r=100, bw=0.4, s=45 0.176503 0.033585
#  RLAC         fisher r=100, bw=0.4, s=32 0.176503 0.033585
#  RLAC         fisher  r=50, bw=0.4, s=43 0.176503 0.033585
#  RLAC         fisher r=300, bw=0.4, s=42 0.176503 0.033585
#  RLAC         fisher r=300, bw=0.4, s=43 0.176503 0.033585
#  RLAC         fisher r=500, bw=0.4, s=42 0.176503 0.033585
#  RLAC         fisher r=500, bw=0.4, s=43 0.176503 0.033585
#  RLAC         fisher r=500, bw=0.4, s=32 0.176503 0.033585
#  RLAC         fisher  r=50, bw=0.4, s=32 0.176503 0.033585
#  RLAC         fisher  r=50, bw=0.4, s=42 0.176503 0.033585
#  RLAC         fisher r=500, bw=0.4, s=45 0.176503 0.033585
#  RLAC         fisher r=500, bw=0.4, s=44 0.176503 0.033585
#  RLAC         fisher r=300, bw=0.4, s=32 0.176503 0.033585
#  RLAC         fisher r=300, bw=0.4, s=44 0.176503 0.033585
#  RLAC         fisher r=300, bw=0.4, s=45 0.176503 0.033585
#  RLAC         fisher  r=50, bw=0.4, s=44 0.176503 0.033585
#  RLAC         fisher r=200, bw=0.4, s=44 0.176503 0.033585
#  RLAC         fisher r=200, bw=0.4, s=45 0.176503 0.033585
#  RLAC    depth_ratio  r=50, bw=0.5, s=32 0.176475 0.033535
#  RLAC       skewness  r=50, bw=0.5, s=32 0.176475 0.033535
#  RLAC    depth_ratio r=300, bw=0.5, s=32 0.176475 0.033535
#  RLAC    depth_ratio  r=50, bw=0.5, s=42 0.176475 0.033535
#  RLAC    depth_ratio  r=50, bw=0.5, s=43 0.176475 0.033535
#  RLAC    depth_ratio r=100, bw=0.5, s=42 0.176475 0.033535
#  RLAC    depth_ratio  r=50, bw=0.5, s=44 0.176475 0.033535
#  RLAC    depth_ratio  r=50, bw=0.5, s=45 0.176475 0.033535
#  RLAC    depth_ratio r=100, bw=0.5, s=32 0.176475 0.033535
#  RLAC       max_kurt  r=50, bw=0.5, s=45 0.176475 0.033535
#  RLAC       max_kurt  r=50, bw=0.5, s=42 0.176475 0.033535
#  RLAC       max_kurt  r=50, bw=0.5, s=43 0.176475 0.033535
#  RLAC       max_kurt  r=50, bw=0.5, s=44 0.176475 0.033535
#  RLAC       max_kurt  r=50, bw=0.5, s=32 0.176475 0.033535
#  RLAC    depth_ratio r=200, bw=0.5, s=43 0.176475 0.033535
#  RLAC    depth_ratio r=200, bw=0.5, s=44 0.176475 0.033535
#  RLAC    depth_ratio r=200, bw=0.5, s=45 0.176475 0.033535
#  RLAC    depth_ratio r=200, bw=0.5, s=32 0.176475 0.033535
#  RLAC    depth_ratio r=500, bw=0.5, s=45 0.176475 0.033535
#  RLAC    depth_ratio r=500, bw=0.5, s=44 0.176475 0.033535
#  RLAC    depth_ratio r=200, bw=0.5, s=42 0.176475 0.033535
#  RLAC    depth_ratio r=500, bw=0.5, s=43 0.176475 0.033535
#  RLAC    depth_ratio r=300, bw=0.5, s=45 0.176475 0.033535
#  RLAC    depth_ratio r=500, bw=0.5, s=32 0.176475 0.033535
#  RLAC    depth_ratio r=500, bw=0.5, s=42 0.176475 0.033535
#  RLAC    depth_ratio r=100, bw=0.5, s=45 0.176475 0.033535
#  RLAC    depth_ratio r=100, bw=0.5, s=44 0.176475 0.033535
#  RLAC    depth_ratio r=100, bw=0.5, s=43 0.176475 0.033535
#  RLAC    depth_ratio r=300, bw=0.5, s=44 0.176475 0.033535
#  RLAC    depth_ratio r=300, bw=0.5, s=43 0.176475 0.033535
#  RLAC    depth_ratio r=300, bw=0.5, s=42 0.176475 0.033535
#  RLAC       skewness r=500, bw=0.5, s=45 0.176475 0.033535
#  RLAC       max_kurt r=300, bw=0.5, s=43 0.176475 0.033535
#  RLAC       skewness r=500, bw=0.5, s=42 0.176475 0.033535
#  RLAC       skewness r=500, bw=0.5, s=44 0.176475 0.033535
#  RLAC       max_kurt r=300, bw=0.5, s=42 0.176475 0.033535
#  RLAC       max_kurt r=300, bw=0.5, s=32 0.176475 0.033535
#  RLAC       max_kurt r=300, bw=0.5, s=45 0.176475 0.033535
#  RLAC       skewness r=500, bw=0.5, s=32 0.176475 0.033535
#  RLAC       max_kurt r=300, bw=0.5, s=44 0.176475 0.033535
#  RLAC       max_kurt r=200, bw=0.5, s=32 0.176475 0.033535
#  RLAC       max_kurt r=100, bw=0.5, s=32 0.176475 0.033535
#  RLAC       max_kurt r=100, bw=0.5, s=42 0.176475 0.033535
#  RLAC       skewness r=500, bw=0.5, s=43 0.176475 0.033535
#  RLAC       skewness r=300, bw=0.5, s=45 0.176475 0.033535
#  RLAC       skewness r=300, bw=0.5, s=42 0.176475 0.033535
#  RLAC       max_kurt r=200, bw=0.5, s=43 0.176475 0.033535
#  RLAC       max_kurt r=200, bw=0.5, s=44 0.176475 0.033535
#  RLAC       max_kurt r=200, bw=0.5, s=45 0.176475 0.033535
#  RLAC       skewness  r=50, bw=0.5, s=42 0.176475 0.033535
#  RLAC       skewness  r=50, bw=0.5, s=43 0.176475 0.033535
#  RLAC       skewness r=100, bw=0.5, s=44 0.176475 0.033535
#  RLAC       skewness r=100, bw=0.5, s=43 0.176475 0.033535
#  RLAC       skewness r=100, bw=0.5, s=42 0.176475 0.033535
#  RLAC       skewness r=100, bw=0.5, s=32 0.176475 0.033535
#  RLAC       skewness  r=50, bw=0.5, s=45 0.176475 0.033535
#  RLAC       skewness  r=50, bw=0.5, s=44 0.176475 0.033535
#  RLAC       max_kurt r=500, bw=0.5, s=32 0.176475 0.033535
#  RLAC       skewness r=100, bw=0.5, s=45 0.176475 0.033535
#  RLAC       max_kurt r=500, bw=0.5, s=43 0.176475 0.033535
#  RLAC       max_kurt r=500, bw=0.5, s=42 0.176475 0.033535
#  RLAC       max_kurt r=200, bw=0.5, s=42 0.176475 0.033535
#  RLAC       skewness r=200, bw=0.5, s=44 0.176475 0.033535
#  RLAC       skewness r=200, bw=0.5, s=45 0.176475 0.033535
#  RLAC       skewness r=300, bw=0.5, s=32 0.176475 0.033535
#  RLAC       max_kurt r=500, bw=0.5, s=44 0.176475 0.033535
#  RLAC       max_kurt r=500, bw=0.5, s=45 0.176475 0.033535
#  RLAC       skewness r=200, bw=0.5, s=32 0.176475 0.033535
#  RLAC       skewness r=200, bw=0.5, s=42 0.176475 0.033535
#  RLAC       skewness r=200, bw=0.5, s=43 0.176475 0.033535
#  RLAC       max_kurt r=100, bw=0.5, s=45 0.176475 0.033535
#  RLAC       max_kurt r=100, bw=0.5, s=44 0.176475 0.033535
#  RLAC       max_kurt r=100, bw=0.5, s=43 0.176475 0.033535
#  RLAC       skewness r=300, bw=0.5, s=43 0.176475 0.033535
#  RLAC       skewness r=300, bw=0.5, s=44 0.176475 0.033535
#  RLAC         fisher r=500, bw=0.5, s=42 0.174807 0.032874
#  RLAC         fisher r=300, bw=0.5, s=42 0.174807 0.032874
#  RLAC         fisher r=300, bw=0.5, s=45 0.174807 0.032874
#  RLAC         fisher r=500, bw=0.5, s=43 0.174807 0.032874
#  RLAC         fisher r=500, bw=0.5, s=32 0.174807 0.032874
#  RLAC         fisher r=200, bw=0.5, s=44 0.174807 0.032874
#  RLAC         fisher r=100, bw=0.5, s=43 0.174807 0.032874
#  RLAC         fisher r=200, bw=0.5, s=32 0.174807 0.032874
#  RLAC         fisher r=200, bw=0.5, s=42 0.174807 0.032874
#  RLAC         fisher r=200, bw=0.5, s=45 0.174807 0.032874
#  RLAC         fisher r=500, bw=0.5, s=44 0.174807 0.032874
#  RLAC         fisher r=500, bw=0.5, s=45 0.174807 0.032874
#  RLAC         fisher r=300, bw=0.5, s=32 0.174807 0.032874
#  RLAC         fisher r=100, bw=0.5, s=45 0.174807 0.032874
#  RLAC         fisher  r=50, bw=0.5, s=44 0.174807 0.032874
#  RLAC         fisher  r=50, bw=0.5, s=45 0.174807 0.032874
#  RLAC         fisher  r=50, bw=0.5, s=42 0.174807 0.032874
#  RLAC         fisher  r=50, bw=0.5, s=43 0.174807 0.032874
#  RLAC         fisher r=200, bw=0.5, s=43 0.174807 0.032874
#  RLAC         fisher  r=50, bw=0.5, s=32 0.174807 0.032874
#  RLAC         fisher r=300, bw=0.5, s=43 0.174807 0.032874
#  RLAC         fisher r=300, bw=0.5, s=44 0.174807 0.032874
#  RLAC         fisher r=100, bw=0.5, s=32 0.174807 0.032874
#  RLAC         fisher r=100, bw=0.5, s=42 0.174807 0.032874
#  RLAC         fisher r=100, bw=0.5, s=44 0.174807 0.032874
#   MDH       Standard               Fixed 0.173097 0.105675
#  RLAC          holes r=500, bw=0.5, s=42 0.000000 0.000000
#  RLAC          holes r=500, bw=0.5, s=43 0.000000 0.000000
#  RLAC          holes r=500, bw=0.5, s=44 0.000000 0.000000
#  RLAC          holes r=500, bw=0.5, s=45 0.000000 0.000000
#  RLAC          holes r=500, bw=0.4, s=43 0.000000 0.000000
#  RLAC          holes r=500, bw=0.4, s=42 0.000000 0.000000
#  RLAC          holes r=500, bw=0.4, s=32 0.000000 0.000000
#  RLAC          holes r=500, bw=0.3, s=45 0.000000 0.000000
#  RLAC          holes r=500, bw=0.3, s=44 0.000000 0.000000
#  RLAC          holes r=500, bw=0.3, s=43 0.000000 0.000000
#  RLAC          holes r=500, bw=0.3, s=42 0.000000 0.000000
#  RLAC          holes r=500, bw=0.3, s=32 0.000000 0.000000
#  RLAC          holes r=500, bw=0.4, s=44 0.000000 0.000000
#  RLAC          holes r=500, bw=0.4, s=45 0.000000 0.000000
#  RLAC          holes r=500, bw=0.5, s=32 0.000000 0.000000
#  RLAC          holes r=300, bw=0.2, s=45 0.000000 0.000000
#  RLAC          holes r=300, bw=0.3, s=32 0.000000 0.000000
#  RLAC          holes r=300, bw=0.3, s=42 0.000000 0.000000
#  RLAC          holes r=300, bw=0.3, s=43 0.000000 0.000000
#  RLAC          holes r=300, bw=0.3, s=44 0.000000 0.000000
#  RLAC          holes r=300, bw=0.5, s=43 0.000000 0.000000
#  RLAC          holes r=300, bw=0.5, s=44 0.000000 0.000000
#  RLAC          holes r=300, bw=0.5, s=45 0.000000 0.000000
#  RLAC          holes r=500, bw=0.2, s=32 0.000000 0.000000
#  RLAC          holes r=500, bw=0.2, s=42 0.000000 0.000000
#  RLAC          holes r=500, bw=0.2, s=43 0.000000 0.000000
#  RLAC          holes r=500, bw=0.2, s=44 0.000000 0.000000
#  RLAC          holes r=500, bw=0.2, s=45 0.000000 0.000000
#  RLAC          holes r=300, bw=0.3, s=45 0.000000 0.000000
#  RLAC          holes r=300, bw=0.4, s=32 0.000000 0.000000
#  RLAC          holes r=300, bw=0.4, s=42 0.000000 0.000000
#  RLAC          holes r=300, bw=0.4, s=43 0.000000 0.000000
#  RLAC          holes r=300, bw=0.4, s=44 0.000000 0.000000
#  RLAC          holes r=300, bw=0.4, s=45 0.000000 0.000000
#  RLAC          holes r=300, bw=0.5, s=32 0.000000 0.000000
#  RLAC          holes r=300, bw=0.5, s=42 0.000000 0.000000
#  RLAC          holes r=200, bw=0.3, s=32 0.000000 0.000000
#  RLAC          holes r=200, bw=0.3, s=42 0.000000 0.000000
#  RLAC          holes r=200, bw=0.3, s=43 0.000000 0.000000
#  RLAC          holes r=200, bw=0.3, s=44 0.000000 0.000000
#  RLAC          holes r=200, bw=0.3, s=45 0.000000 0.000000
#  RLAC          holes r=200, bw=0.4, s=32 0.000000 0.000000
#  RLAC          holes r=200, bw=0.4, s=42 0.000000 0.000000
#  RLAC          holes r=200, bw=0.4, s=43 0.000000 0.000000
#  RLAC          holes r=100, bw=0.5, s=43 0.000000 0.000000
#  RLAC          holes r=100, bw=0.5, s=44 0.000000 0.000000
#  RLAC          holes r=100, bw=0.5, s=45 0.000000 0.000000
#  RLAC          holes r=200, bw=0.2, s=32 0.000000 0.000000
#  RLAC          holes r=200, bw=0.2, s=42 0.000000 0.000000
#  RLAC          holes r=200, bw=0.2, s=43 0.000000 0.000000
#  RLAC          holes r=200, bw=0.2, s=44 0.000000 0.000000
#  RLAC          holes r=200, bw=0.2, s=45 0.000000 0.000000
#  RLAC          holes r=100, bw=0.5, s=42 0.000000 0.000000
#  RLAC          holes r=100, bw=0.5, s=32 0.000000 0.000000
#  RLAC          holes r=100, bw=0.4, s=45 0.000000 0.000000
#  RLAC          holes r=100, bw=0.4, s=44 0.000000 0.000000
#  RLAC          holes r=100, bw=0.4, s=43 0.000000 0.000000
#  RLAC          holes  r=50, bw=0.2, s=42 0.000000 0.000000
#  RLAC          holes r=300, bw=0.2, s=42 0.000000 0.000000
#  RLAC          holes r=300, bw=0.2, s=43 0.000000 0.000000
#  RLAC          holes r=300, bw=0.2, s=32 0.000000 0.000000
#  RLAC          holes r=200, bw=0.5, s=45 0.000000 0.000000
#  RLAC          holes r=200, bw=0.4, s=44 0.000000 0.000000
#  RLAC          holes r=200, bw=0.4, s=45 0.000000 0.000000
#  RLAC          holes r=200, bw=0.5, s=43 0.000000 0.000000
#  RLAC          holes r=200, bw=0.5, s=44 0.000000 0.000000
#  RLAC          holes r=200, bw=0.5, s=32 0.000000 0.000000
#  RLAC          holes r=200, bw=0.5, s=42 0.000000 0.000000
#  RLAC          holes  r=50, bw=0.3, s=45 0.000000 0.000000
#  RLAC          holes  r=50, bw=0.4, s=32 0.000000 0.000000
#  RLAC          holes  r=50, bw=0.3, s=43 0.000000 0.000000
#  RLAC          holes  r=50, bw=0.3, s=44 0.000000 0.000000
#  RLAC          holes  r=50, bw=0.3, s=42 0.000000 0.000000
#  RLAC          holes  r=50, bw=0.3, s=32 0.000000 0.000000
#  RLAC          holes  r=50, bw=0.2, s=44 0.000000 0.000000
#  RLAC          holes  r=50, bw=0.2, s=45 0.000000 0.000000
#  RLAC          holes  r=50, bw=0.2, s=32 0.000000 0.000000
#  RLAC          holes r=300, bw=0.2, s=44 0.000000 0.000000
#  RLAC          holes  r=50, bw=0.2, s=43 0.000000 0.000000
#  RLAC          holes  r=50, bw=0.4, s=42 0.000000 0.000000
#  RLAC          holes  r=50, bw=0.4, s=44 0.000000 0.000000
#  RLAC          holes  r=50, bw=0.4, s=45 0.000000 0.000000
#  RLAC          holes  r=50, bw=0.5, s=32 0.000000 0.000000
#  RLAC          holes  r=50, bw=0.4, s=43 0.000000 0.000000
#  RLAC          holes  r=50, bw=0.5, s=42 0.000000 0.000000
#  RLAC          holes  r=50, bw=0.5, s=43 0.000000 0.000000
#  RLAC          holes  r=50, bw=0.5, s=45 0.000000 0.000000
#  RLAC          holes  r=50, bw=0.5, s=44 0.000000 0.000000
#  RLAC          holes r=100, bw=0.2, s=42 0.000000 0.000000
#  RLAC          holes r=100, bw=0.2, s=43 0.000000 0.000000
#  RLAC          holes r=100, bw=0.2, s=44 0.000000 0.000000
#  RLAC          holes r=100, bw=0.2, s=32 0.000000 0.000000
#  RLAC          holes r=100, bw=0.2, s=45 0.000000 0.000000
#  RLAC          holes r=100, bw=0.3, s=32 0.000000 0.000000
#  RLAC          holes r=100, bw=0.3, s=43 0.000000 0.000000
#  RLAC          holes r=100, bw=0.3, s=42 0.000000 0.000000
#  RLAC          holes r=100, bw=0.3, s=44 0.000000 0.000000
#  RLAC          holes r=100, bw=0.3, s=45 0.000000 0.000000
#  RLAC          holes r=100, bw=0.4, s=32 0.000000 0.000000
#  RLAC          holes r=100, bw=0.4, s=42 0.000000 0.000000
